# %%
from PIL import Image
for face in range(1, 7):
    img = Image.open(f"dice_{face}_color.png")
    img = img.resize((img.width * 4, img.height * 4), Image.NEAREST)
    img.save(f"Upscale/513x/dice_{face}_color_120x.png")
